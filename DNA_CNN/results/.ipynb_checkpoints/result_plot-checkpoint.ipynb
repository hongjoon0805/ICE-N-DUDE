# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
k_arr = np.arange(1,21) * 10

N_DUDE_k = [0.79764,0.65991,0.56240,0.48474,0.46113,0.41392,0.41241,0.39203,0.37082,0.37529,0.36900,0.35598,0.35793,0.35125,0.35792,0.35534,0.35788,0.35414,0.35347,0.35826]
ICE_k = [0.89140,0.61005,0.51882,0.45694,0.42671,0.40217,0.39194,0.38621,0.37367,0.37190,0.37741,0.36719,0.36552,0.37331,0.36744,0.37693,0.37981,0.38226,0.38256,0.38305]
N_DUDE_16_k = [0.80838,0.62838,0.55907,0.51376,0.46290,0.48486,0.44659,0.40644,0.41368,0.39888,0.42143,0.43594,0.43245,0.40807,0.41500,0.40992,0.43785,0.42835,0.44850,0.50269]
ICE_16_k = [1.16147,0.74417,0.62123,0.56164,0.53915,0.49556,0.47753,0.47624,0.46314,0.46294,0.45038,0.44903,0.45537,0.44952,0.44303,0.43537,0.45332,0.46982,0.44893,0.47001]
BW_1st_k = [1.46889,1.06930,0.86182,0.78092,0.70401,0.65977,0.62047,0.60848,0.57982,0.55701,0.54741,0.56337,0.55506,0.53852,0.54221,0.53784,0.54910,0.54142,0.55350,0.55551]
BW_2nd_k = [1.47191,1.02508,0.85999,0.77366,0.68744,0.63245,0.60312,0.57188,0.54936,0.53561,0.51940,0.52394,0.51821,0.51517,0.51253,0.49602,0.51784,0.50968,0.52159,0.53693]

plt.plot(k_arr, N_DUDE_k, linestyle = '-', label = 'N-DUDE (5)', marker = '^')
plt.plot(k_arr, ICE_k, linestyle = '-', label = 'ICE-N-DUDE (5)', marker = 's')
plt.plot(k_arr, N_DUDE_16_k, linestyle = '-', label = 'N-DUDE (16)', marker = '.')
plt.plot(k_arr, ICE_16_k, linestyle = '-', label = 'ICE-N-DUDE (16)', marker = '1')
plt.plot(k_arr, BW_1st_k, linestyle = '-', label = 'BW_1st (5)', marker = 'x')
plt.plot(k_arr, BW_2nd_k, linestyle = '-', label = 'BW_2nd (5)', marker = '*')


plt.ylim(0.3,1.0)
plt.yticks([0.3,0.4,0.5,0.6,0.7,0.8,0.9,1.0],fontsize = 15)
plt.xticks([20,40,60,80,100,120,140,160,180,200], fontsize = 15)

plt.xlabel('Window size k', fontsize = 20)
plt.ylabel('Error rate / $\delta$', fontsize = 20)

plt.legend(loc = 'upper right', frameon = True)
plt.savefig('figure/DNA_error_k.pdf', bbox_inches='tight')

print(np.min(N_DUDE_k))
print(np.min(ICE_k))

print(np.argmin(N_DUDE_k))
print(np.argmin(ICE_k))
# Out:
# 0.35125
# 0.36552
# 13
# 12

# %%
delta_arr = np.arange(1,41) / float(100)
ICE_delta = [0.37120,0.37202,0.37289,0.36669,0.37404,0.37009,0.37280,0.37235,0.38115,0.37052,0.37516,0.37605,0.37663,0.37455,0.37748,0.36986,0.37051,0.37318,0.36730,0.37796,0.37362,0.37801,0.36999,0.37099,0.37467,0.37420,0.37014,0.37028,0.37020,0.37886,0.37111,0.38079,0.37499,0.37489,0.37473,0.36818,0.37308,0.37685,0.37044,0.37369]
ICE_16_delta = [0.43411,0.43234,0.42975,0.42881,0.43003,0.44582,0.45480,0.43626,0.44216,0.43498,0.43280,0.45186,0.44253,0.43775,0.45240,0.45101,0.44866,0.43902,0.44494,0.44604,0.44020,0.45864,0.44559,0.44287,0.43993,0.44491,0.43384,0.45189,0.44907,0.43245,0.45299,0.46464,0.44627,0.44981,0.45519,0.44887,0.43278,0.46575,0.45058,0.45988]
BW_1st_delta = [0.99297,0.93406,0.91600,0.88075,0.68917,0.50745,0.46318,0.37174,0.35966,0.34137,0.34148,0.34302,0.34053,0.33944,0.34564,0.34682,0.35213,0.35742,0.37324,0.37516,0.38670,0.39139,0.40808,0.40924,0.43573,0.44021,0.44785,0.47149,0.46524,0.47128,0.48867,0.48757,0.49795,0.51785,0.50476,0.51659,0.52003,0.53389,0.52496,0.53699]
BW_2nd_delta = [0.37943,0.33901,0.34914,0.34837,0.35793,0.36686,0.37064,0.38846,0.38219,0.37783,0.38823,0.37859,0.39286,0.40756,0.40794,0.40590,0.40815,0.40826,0.41823,0.41543,0.41642,0.41775,0.42048,0.41227,0.41126,0.42898,0.43080,0.43578,0.43411,0.43692,0.44870,0.44390,0.45373,0.48087,0.48051,0.47602,0.47283,0.48764,0.49402,0.51432]

plt.plot(delta_arr, N_DUDE_k[14] * np.ones(40), linestyle = '-', label = 'N-DUDE', marker = '^')
plt.plot(delta_arr, ICE_delta, linestyle = '-', label = 'ICE-N-DUDE', marker = 's')
plt.plot(delta_arr, BW_1st_delta, linestyle = '-', label = 'BW_1st with N-DUDE', marker = '.')
plt.plot(delta_arr, BW_2nd_delta, linestyle = '-', label = 'BW_2nd with N-DUDE', marker = '1')
plt.plot(delta_arr, N_DUDE_16_k[14] * np.ones(40), linestyle = '-', label = 'N-DUDE with 16 mapping', marker = '.')
plt.plot(delta_arr, ICE_16_delta, linestyle = '-', label = 'ICE-N-DUDE with 16 mapping', marker = '1')

plt.ylim(0.3,1.0)

plt.xlabel('assumed $\delta$', fontsize = 20)
plt.ylabel('Error rate', fontsize = 20)

plt.legend(loc = 'upper right', frameon = True)
plt.savefig('figure/DNA_error_delta.pdf', bbox_inches='tight')

print(np.max(ICE_delta))
print((N_DUDE_k[14]))
# Out:
# 0.38115
# 0.35792

# %%
ICE_train = np.array([0.69571,0.75566,0.67064,0.67987,0.64666,0.65278,0.63448,0.64634,0.63256,0.63837])
ICE_valid = np.array([0.70432,0.66241,0.66370,0.65855,0.65844,0.65621,0.65601,0.65391,0.65340,0.65359])

NDUDE_train = np.array([0.66975,0.66328,0.66013,0.65793,0.65648,0.65527,0.65428,0.65336,0.65278,0.65210])

iteration = np.arange(10)+1
    
plt.plot(iteration, NDUDE_train, linestyle = '-', label = 'N-DUDE', marker = '*')
plt.plot(iteration, ICE_train, linestyle = '-', label = 'ICE train', marker = '.')
plt.plot(iteration, ICE_valid, linestyle = '-', label = 'ICE valid', marker = '.')

plt.xlim(1,10)
plt.xticks(iteration)


plt.legend(loc = 'upper right', frameon = True)

# %%
ICE_valid = np.array([0.70432,0.66241,0.66370,0.65855,0.65844,0.65621,0.65601,0.65391,0.65340,0.65359])

NDUDE_train = np.array([0.66975,0.66328,0.66013,0.65793,0.65648,0.65527,0.65428,0.65336,0.65278,0.65210])

iteration = np.arange(10)+1

plt.plot(iteration, np.abs(ICE_valid - NDUDE_train), linestyle = '-', marker = '*')

plt.xlim(1,10)
plt.xticks(iteration)

plt.ylim(-0.1, 0.3)
plt.yticks([-0.1, 0.0, 0.1, 0.2, 0.3])

plt.xlabel('Iterations', fontsize = 20)
plt.ylabel("$|\~L(w^{\star}) - \~L(w^{(t)})|$", fontsize = 20)

plt.legend(loc = 'upper right', frameon = True)

plt.savefig('figure/DNA_loss.pdf', bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.

# %%
DNA_PI_diff = [0.03794,0.05114,0.03594,0.03669,0.03230,0.03214,0.03054,0.03376,0.03262,0.03128]
plt.plot(iteration, DNA_PI_diff, label = 'DNA', linestyle = '-', marker = '*')

plt.xlim(1,10)
plt.xticks(iteration)

plt.ylim(-0.1, 0.3)
plt.yticks([-0.1, 0.0, 0.1, 0.2, 0.3])

plt.xlabel('Iterations', fontsize = 20)
plt.ylabel("$||\Pi-\Pi^{(t)}||_1$", fontsize = 20)

plt.legend(loc = 'upper right', frameon = True)

plt.savefig('figure/DNA_PI.pdf', bbox_inches='tight')

# %%
ICE_delta = [0.37120,0.37202,0.37289,0.36669,0.37404,0.37009,0.37280,0.37235,0.38115,0.37052,0.37516,0.37605,0.37663,0.37455,0.37748,0.36986,0.37051,0.37318,0.36730,0.37796,0.37362,0.37801,0.36999,0.37099,0.37467,0.37420,0.37014,0.37028,0.37020,0.37886,0.37111,0.38079,0.37499,0.37489,0.37473,0.36818,0.37308,0.37685,0.37044,0.37369]
ICE_16_delta = [0.43411,0.43234,0.42975,0.42881,0.43003,0.44582,0.45480,0.43626,0.44216,0.43498,0.43280,0.45186,0.44253,0.43775,0.45240,0.45101,0.44866,0.43902,0.44494,0.44604,0.44020,0.45864,0.44559,0.44287,0.43993,0.44491,0.43384,0.45189,0.44907,0.43245,0.45299,0.46464,0.44627,0.44981,0.45519,0.44887,0.43278,0.46575,0.45058,0.45988]
BW_1st_delta = [0.99297,0.93406,0.91600,0.88075,0.68917,0.50745,0.46318,0.37174,0.35966,0.34137,0.34148,0.34302,0.34053,0.33944,0.34564,0.34682,0.35213,0.35742,0.37324,0.37516,0.38670,0.39139,0.40808,0.40924,0.43573,0.44021,0.44785,0.47149,0.46524,0.47128,0.48867,0.48757,0.49795,0.51785,0.50476,0.51659,0.52003,0.53389,0.52496,0.53699]
BW_2nd_delta = [0.37943,0.33901,0.34914,0.34837,0.35793,0.36686,0.37064,0.38846,0.38219,0.37783,0.38823,0.37859,0.39286,0.40756,0.40794,0.40590,0.40815,0.40826,0.41823,0.41543,0.41642,0.41775,0.42048,0.41227,0.41126,0.42898,0.43080,0.43578,0.43411,0.43692,0.44870,0.44390,0.45373,0.48087,0.48051,0.47602,0.47283,0.48764,0.49402,0.51432]


data = [ICE_delta, ICE_16_delta, BW_1st_delta, BW_2nd_delta]


# don't show outlier points
plt.figure()
plt.boxplot(data, labels = ['ICE (5)', 'ICE (16)','BW_1st (5)','BW_2nd (5)'])
plt.hlines(N_DUDE_k[14], 0, 5, label = 'N-DUDE (5)', color = '#1f77b4', linestyle = '-.')
plt.hlines(N_DUDE_16_k[14], 0, 5, label = 'N-DUDE (16)', color = '#2ca02c', linestyle = '--')

plt.xlabel('Schemes', fontsize=20)
plt.ylabel('Error rate / $\delta$', fontsize=20)

plt.ylim(0.3,1.0)
plt.yticks([0.3,0.4,0.5,0.6,0.7,0.8,0.9,1.0],fontsize = 15)
plt.xticks(fontsize = 14)

plt.legend(loc = 'upper left', frameon = True, fontsize = 12)

plt.savefig('figure/DNA_error_delta_box.pdf', bbox_inches='tight')
