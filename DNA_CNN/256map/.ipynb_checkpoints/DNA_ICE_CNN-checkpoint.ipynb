# %%
from core import *
from tools import *
import numpy as np
import os
import tensorflow as tf
import keras as K

import sys
import argparse
# Out:
# Using TensorFlow backend.

# %%
PI_true = array([ [ 0.8122,  0.0034,  0.0894,  0.0950],
                  [ 0.0096,  0.8237,  0.0808,  0.0859],
                  [ 0.1066,  0.0436,  0.7774,  0.0724],
                  [ 0.0704,  0.0690,  0.0889,  0.7717]])
x, z = load_DNA(PI_true)

try:
    parser = argparse.ArgumentParser()
    
    parser.add_argument("--k", help="window size k", type=int)
    parser.add_argument("--d", help="Assumed delta", type=float)
    
    args = parser.parse_args()
    
    result_name = sys.argv[0]
    k = args.k
    assumed_delta = args.d
    n = len(x)
    param_name = "ICE_%03d_%.2f"%(k, assumed_delta)
        
except:
    result_name = "test"
    k = 150
    assumed_delta = 0.40
    n = int(1e4)
    param_name = "test_%03d_%.2f"%(k, assumed_delta)
    
nb_x_classes, nb_z_classes = 4, 4
assumed_PI = sym_mat(4, assumed_delta)
x, z = x[:n], z[:n]
# Out:
# usage: ipykernel_launcher.py [-h] [--k K] [--d D]
# ipykernel_launcher.py: error: unrecognized arguments: -f /run/user/1002/jupyter/kernel-4c36d800-3a3d-430a-b950-c45ed84c65dd.json

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]='0, 1, 2, 3'

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
K.backend.set_session(session)

# %%
f = open('results/'+result_name,'a')
print("k: %d assumed_delta: %.2f"%(k,assumed_delta))

ICE_N_DUDE = ICE_Process(n, k, nb_x_classes, nb_z_classes, x, z, param_name = param_name)
Estimated_PI = ICE_N_DUDE.ICE(assumed_PI)
print(Estimated_PI)

DE = Denoising_Process(n, k, nb_x_classes, nb_z_classes, x, z, param_name = param_name)
normalized_error, x_hat = DE.N_DUDE(Estimated_PI)
f.write("%d %.2f %.5f\n"%(k, assumed_delta, normalized_error))
print(normalized_error)
# Out:
# k: 150 assumed_delta: 0.40
# Train on 10 samples, validate on 10 samples
# Epoch 1/20
# 10/10 [==============================] - 4s 440ms/step - loss: 2.5641 - val_loss: 2.5058
# Epoch 2/20
# 10/10 [==============================] - 0s 11ms/step - loss: 2.5041 - val_loss: 2.4921
# Epoch 3/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4916 - val_loss: 2.4880
# Epoch 4/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4878 - val_loss: 2.4858
# Epoch 5/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4856 - val_loss: 2.4844
# Epoch 6/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4843 - val_loss: 2.4835
# Epoch 7/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4834 - val_loss: 2.4828
# Epoch 8/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4828 - val_loss: 2.4823
# Epoch 9/20
# 10/10 [==============================] - 0s 8ms/step - loss: 2.4823 - val_loss: 2.4820
# Epoch 10/20
# 10/10 [==============================] - 0s 8ms/step - loss: 2.4820 - val_loss: 2.4817
# Epoch 11/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4817 - val_loss: 2.4815
# Epoch 12/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4815 - val_loss: 2.4814
# Epoch 13/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4814 - val_loss: 2.4813
# Epoch 14/20
# 10/10 [==============================] - 0s 8ms/step - loss: 2.4813 - val_loss: 2.4812
# Epoch 15/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4812 - val_loss: 2.4811
# Epoch 16/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4811 - val_loss: 2.4811
# Epoch 17/20
# 10/10 [==============================] - 0s 11ms/step - loss: 2.4811 - val_loss: 2.4810
# Epoch 18/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4810 - val_loss: 2.4810
# Epoch 19/20
# 10/10 [==============================] - 0s 7ms/step - loss: 2.4810 - val_loss: 2.4810
# Epoch 20/20
# 10/10 [==============================] - 0s 6ms/step - loss: 2.4810 - val_loss: 2.4810
# [[0.25929708 0.20845326 0.30286998 0.22937968]
#  [0.25969856 0.20876933 0.30229389 0.22923822]
#  [0.25919816 0.20888027 0.30253525 0.22938633]
#  [0.2602054  0.20869729 0.3019014  0.22919592]]
# Train on 10 samples, validate on 10 samples
# Epoch 1/20
# 10/10 [==============================] - 1s 146ms/step - loss: 73197.3719 - val_loss: 73194.3031
# Epoch 2/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73194.1813 - val_loss: 73193.3344
# Epoch 3/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73193.3000 - val_loss: 73193.0484
# Epoch 4/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73193.0312 - val_loss: 73192.8531
# Epoch 5/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73192.8359 - val_loss: 73192.7281
# Epoch 6/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73192.7109 - val_loss: 73192.6062
# Epoch 7/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73192.6016 - val_loss: 73192.5469
# Epoch 8/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73192.5406 - val_loss: 73192.4844
# Epoch 9/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73192.4844 - val_loss: 73192.4375
# Epoch 10/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73192.4375 - val_loss: 73192.3906
# Epoch 11/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73192.3875 - val_loss: 73192.3484
# Epoch 12/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73192.3344 - val_loss: 73192.2703
# Epoch 13/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73192.2641 - val_loss: 73192.1750
# Epoch 14/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73192.1625 - val_loss: 73192.0594
# Epoch 15/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73192.0484 - val_loss: 73191.8750
# Epoch 16/20
# 10/10 [==============================] - 0s 9ms/step - loss: 73191.8562 - val_loss: 73191.6500
# Epoch 17/20
# 10/10 [==============================] - 0s 10ms/step - loss: 73191.6344 - val_loss: 73191.3531
# Epoch 18/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73191.3094 - val_loss: 73190.9844
# Epoch 19/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73190.9406 - val_loss: 73190.5094
# Epoch 20/20
# 10/10 [==============================] - 0s 8ms/step - loss: 73190.4781 - val_loss: 73189.9563
# [[0.25912142 0.20833321 0.30176549 0.23077988]
#  [0.25962031 0.20874621 0.30249891 0.22913456]
#  [0.25966373 0.20871874 0.3024744  0.22914313]
#  [0.25999608 0.20900303 0.30286316 0.22813773]]
# Train on 10 samples, validate on 10 samples
# Epoch 1/20
# 10/10 [==============================] - 1s 149ms/step - loss: 79871.2109 - val_loss: 79864.5281
# Epoch 2/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79864.0156 - val_loss: 79860.3875
# Epoch 3/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79860.1484 - val_loss: 79858.2234
# Epoch 4/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79858.0312 - val_loss: 79857.0531
# Epoch 5/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79856.9250 - val_loss: 79856.3828
# Epoch 6/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79856.3344 - val_loss: 79856.0203
# Epoch 7/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79856.0031 - val_loss: 79855.8078
# Epoch 8/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79855.7969 - val_loss: 79855.6766
# Epoch 9/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.6562 - val_loss: 79855.5875
# Epoch 10/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79855.5906 - val_loss: 79855.5500
# Epoch 11/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.5406 - val_loss: 79855.5109
# Epoch 12/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79855.5094 - val_loss: 79855.4859
# Epoch 13/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79855.4875 - val_loss: 79855.4625
# Epoch 14/20
# 10/10 [==============================] - 0s 7ms/step - loss: 79855.4578 - val_loss: 79855.4375
# Epoch 15/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.4453 - val_loss: 79855.4375
# Epoch 16/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.4375 - val_loss: 79855.4187
# Epoch 17/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.4219 - val_loss: 79855.4187
# Epoch 18/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.4219 - val_loss: 79855.4172
# Epoch 19/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.4187 - val_loss: 79855.4125
# Epoch 20/20
# 10/10 [==============================] - 0s 8ms/step - loss: 79855.4094 - val_loss: 79855.3813
# [[0.2596143  0.20869394 0.30239507 0.22929669]
#  [0.25959526 0.20870252 0.30238602 0.22931619]
#  [0.2595897  0.20869913 0.30241917 0.229292  ]
#  [0.25960071 0.20870443 0.30239976 0.2292951 ]]
# [[0.2596143  0.20869394 0.30239507 0.22929669]
#  [0.25959526 0.20870252 0.30238602 0.22931619]
#  [0.2595897  0.20869913 0.30241917 0.229292  ]
#  [0.25960071 0.20870443 0.30239976 0.2292951 ]]
# Train on 10 samples, validate on 10 samples
# Epoch 1/10
# 10/10 [==============================] - 2s 157ms/step - loss: 317777.2250 - val_loss: 317777.2125
# Epoch 2/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.1875 - val_loss: 317777.1437
# Epoch 3/10
# 10/10 [==============================] - 0s 6ms/step - loss: 317777.1625 - val_loss: 317777.1875
# Epoch 4/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.1500 - val_loss: 317777.1188
# Epoch 5/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.1187 - val_loss: 317777.0500
# Epoch 6/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.0375 - val_loss: 317777.0375
# Epoch 7/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.0500 - val_loss: 317776.9938
# Epoch 8/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.0000 - val_loss: 317777.0125
# Epoch 9/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317777.0125 - val_loss: 317777.0000
# Epoch 10/10
# 10/10 [==============================] - 0s 7ms/step - loss: 317776.9875 - val_loss: 317776.9437
# 5.010035122930256
